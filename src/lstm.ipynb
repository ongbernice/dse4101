# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score

# %%
# Load the dataset
stocks_data = pd.read_csv("../data/final_merged_data.csv", parse_dates=["Date"])
stocks_data = stocks_data.iloc[:, 1:]

# %% [markdown]
# # Data Preparation

# %%
# get names of feature columns
features = stocks_data.drop(columns=['Date', 'Ticker', 'Risk_Premium', 'Risk_Premium_lag_1']).columns
target = 'Risk_Premium'

# impute missing values
imputer = SimpleImputer(strategy='mean')
stocks_data[features] = imputer.fit_transform(stocks_data[features])

# ticker names
tickers = stocks_data['Ticker'].unique()

# %%
def create_sequences(X, y, n_steps=12):
    """
    Create sliding window sequences for RNN models.
    
    :param X: Feature DataFrame
    :param y: Target series
    :param n_steps: Number of timesteps for each input sequence
    :return: Arrays of input sequences (X_seq) and corresponding targets (y_seq)
    """
    X_seq, y_seq = [], []
    for i in range(len(X) - n_steps):
        X_seq.append(X.iloc[i:i + n_steps].values)  # Get sequence of features
        y_seq.append(y.iloc[i + n_steps])          # Get corresponding target value
    
    return np.array(X_seq), np.array(y_seq)

# Dictionaries to store sequences and scalers per ticker
X_tickers = {}
y_tickers = {}
scalers = {}

# Loop through each ticker first
for ticker in tickers:
    # Select rows for the current ticker
    ticker_data = stocks_data[stocks_data['Ticker'] == ticker]

    # Separate features (X) and target variable (y)
    X_df = ticker_data[features]  # Select feature columns
    y_df = ticker_data[['Risk_Premium']]  # Select target column

    # Create separate scalers for X and y
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    # Fit & transform the features and target separately
    X_scaled = scaler_x.fit_transform(X_df)
    y_scaled = scaler_y.fit_transform(y_df)

    # Convert back to DataFrame for sequence creation
    X_scaled_df = pd.DataFrame(X_scaled, columns=X_df.columns, index=X_df.index)
    y_scaled_df = pd.DataFrame(y_scaled, columns=y_df.columns, index=y_df.index)

    # Create sequences
    X_seq, y_seq = create_sequences(X_scaled_df, y_scaled_df)

    # --- Split the sequences into training and testing sets ---
    # Ensure there are at least 160 training and 100 test samples
    X_train = X_seq[:-100]
    y_train = y_seq[:-100]
    X_test = X_seq[-100:]
    y_test = y_seq[-100:]

    # Store results in dictionaries
    X_tickers[ticker] = {'train': X_train, 'test': X_test}
    y_tickers[ticker] = {'train': y_train, 'test': y_test}
    
    # Store scalers for later inverse transformation
    scalers[ticker] = {'X_scaler': scaler_x, 'y_scaler': scaler_y}

# %% [markdown]
# # Model Training & Evaluation per Ticker

# %%
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))  # Explicit Input layer
    model.add(LSTM(50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))  # Single output for risk premium
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model

# %%
# to store evaluation results for each ticker
results_df = []

for ticker in X_tickers:
    X_train = X_tickers[ticker]['train']  # Shape: (num_train_samples, sequence_length, num_features)
    y_train = y_tickers[ticker]['train']
    X_test = X_tickers[ticker]['test']    # Shape: (100, sequence_length, num_features)
    y_test = y_tickers[ticker]['test']
    
    # Get scalers for the ticker
    scaler_y = scalers[ticker]['y_scaler']

    # Define the input shape based on the training set
    input_shape = X_train.shape[1:]  # (sequence_length, num_features)
    
    # Create and train the model
    model = create_lstm_model(input_shape)
    model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred_scaled = model.predict(X_test).flatten().reshape(-1, 1)

    # Inverse transform predictions and true values
    y_pred = scaler_y.inverse_transform(y_pred_scaled).flatten()
    y_test_original = scaler_y.inverse_transform(y_test).flatten()

    # Compute the R-squared value
    r2 = r2_score(y_test_original, y_pred)
    
    # Store results
    for month_idx in range(len(y_test_original)):
        results_df.append({
            'Ticker': ticker,
            'Month': month_idx,
            'y_test': y_test_original[month_idx],
            'y_pred': y_pred[month_idx],
            'R_squared': r2
        })
    print(f"Ticker: {ticker} | Test Samples: {X_test.shape[0]} | R-squared: {r2:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: AAPL | Test Samples: 100 | R-squared: -0.6604
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Ticker: ACIW | Test Samples: 100 | R-squared: -1.0103
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: ADBE | Test Samples: 100 | R-squared: -0.8303
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: ADI | Test Samples: 100 | R-squared: -2.6771
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: ADP | Test Samples: 100 | R-squared: -0.2157
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: ADSK | Test Samples: 100 | R-squared: -1.3188
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: ADTN | Test Samples: 100 | R-squared: -0.1635
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Ticker: AEHR | Test Samples: 100 | R-squared: -0.1994
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: AGYS | Test Samples: 100 | R-squared: -0.1493
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: ALNT | Test Samples: 100 | R-squared: -0.5936
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: ALOT | Test Samples: 100 | R-squared: -0.1191
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: AMAT | Test Samples: 100 | R-squared: -0.3278
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: AMD | Test Samples: 100 | R-squared: -0.4292
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: AMKR | Test Samples: 100 | R-squared: -0.1386
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: ANSS | Test Samples: 100 | R-squared: -0.1270
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: APH | Test Samples: 100 | R-squared: -3.5768
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: ARW | Test Samples: 100 | R-squared: -0.2223
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: ASGN | Test Samples: 100 | R-squared: -0.0764
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: ASML | Test Samples: 100 | R-squared: -0.1823
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: ASTC | Test Samples: 100 | R-squared: -0.2950
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: ASUR | Test Samples: 100 | R-squared: -0.3237
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: ASYS | Test Samples: 100 | R-squared: -0.7196
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: AVNW | Test Samples: 100 | R-squared: -0.4980
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: AVT | Test Samples: 100 | R-squared: -0.5974
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: AWRE | Test Samples: 100 | R-squared: -0.6418
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: AXTI | Test Samples: 100 | R-squared: -0.4986
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: AZPN | Test Samples: 100 | R-squared: -0.5253
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: BDC | Test Samples: 100 | R-squared: -0.0825
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: BELFA | Test Samples: 100 | R-squared: -0.1266
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: BELFB | Test Samples: 100 | R-squared: -0.0012
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: BHE | Test Samples: 100 | R-squared: -0.2230
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: BKTI | Test Samples: 100 | R-squared: -0.7619
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: BMI | Test Samples: 100 | R-squared: -0.6711
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: BOSC | Test Samples: 100 | R-squared: -0.4154
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: CACI | Test Samples: 100 | R-squared: -0.0720
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: CCRD | Test Samples: 100 | R-squared: -0.1304
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CDNS | Test Samples: 100 | R-squared: -0.3475
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: CGNX | Test Samples: 100 | R-squared: -0.4929
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: CHKP | Test Samples: 100 | R-squared: -0.1422
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: CIEN | Test Samples: 100 | R-squared: -1.1090
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: CLFD | Test Samples: 100 | R-squared: -0.3211
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: CLMB | Test Samples: 100 | R-squared: -0.4222
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CLRO | Test Samples: 100 | R-squared: -0.4605
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: CLS | Test Samples: 100 | R-squared: -0.2026
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: CMTL | Test Samples: 100 | R-squared: -0.1835
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CNXN | Test Samples: 100 | R-squared: -1.2285
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: COHR | Test Samples: 100 | R-squared: -0.2544
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: COHU | Test Samples: 100 | R-squared: -0.5002
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: CPSH | Test Samples: 100 | R-squared: -0.3538
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CRUS | Test Samples: 100 | R-squared: -0.3307
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: CSCO | Test Samples: 100 | R-squared: -0.6325
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CSGS | Test Samples: 100 | R-squared: -0.1985
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CSPI | Test Samples: 100 | R-squared: -0.3543
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: CTS | Test Samples: 100 | R-squared: -0.1212
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: CTSH | Test Samples: 100 | R-squared: -0.5714
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: DAIO | Test Samples: 100 | R-squared: -0.0160
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: DAKT | Test Samples: 100 | R-squared: -0.1705
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: DDD | Test Samples: 100 | R-squared: -0.2480
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: DGII | Test Samples: 100 | R-squared: -0.4038
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: DIOD | Test Samples: 100 | R-squared: -0.0418
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: DJCO | Test Samples: 100 | R-squared: -0.0459
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: DOX | Test Samples: 100 | R-squared: -0.8262
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: DSWL | Test Samples: 100 | R-squared: -0.2633
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: DXC | Test Samples: 100 | R-squared: -0.0573
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: EEFT | Test Samples: 100 | R-squared: -0.5722
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: EGHT | Test Samples: 100 | R-squared: -0.7748
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: ELSE | Test Samples: 100 | R-squared: -0.9710
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: ELTK | Test Samples: 100 | R-squared: 0.0142
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: EMKR | Test Samples: 100 | R-squared: -0.1133
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: ERIC | Test Samples: 100 | R-squared: -0.6833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Ticker: ESE | Test Samples: 100 | R-squared: -0.1636
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: FARO | Test Samples: 100 | R-squared: -0.0279
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: FEIM | Test Samples: 100 | R-squared: -0.5872
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: FI | Test Samples: 100 | R-squared: -0.2188
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: FICO | Test Samples: 100 | R-squared: -0.1389
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: FLEX | Test Samples: 100 | R-squared: -0.4479
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: FORTY | Test Samples: 100 | R-squared: -0.5627
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: GEN | Test Samples: 100 | R-squared: -0.1978
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: GIB | Test Samples: 100 | R-squared: -0.4974
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: GILT | Test Samples: 100 | R-squared: -0.0091
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: GLW | Test Samples: 100 | R-squared: -0.2652
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: GNSS | Test Samples: 100 | R-squared: -2.6239
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: HCKT | Test Samples: 100 | R-squared: -0.6930
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: HLIT | Test Samples: 100 | R-squared: -0.1980
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: HPQ | Test Samples: 100 | R-squared: -0.3091
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: IBM | Test Samples: 100 | R-squared: -0.1403
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: IDCC | Test Samples: 100 | R-squared: -21.2833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: INOD | Test Samples: 100 | R-squared: -0.0544
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: INTC | Test Samples: 100 | R-squared: -1.2310
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: INTT | Test Samples: 100 | R-squared: -1.2746
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Ticker: INTU | Test Samples: 100 | R-squared: -1.0800
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: INTZ | Test Samples: 100 | R-squared: -0.0319
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: INUV | Test Samples: 100 | R-squared: -0.0569
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: IT | Test Samples: 100 | R-squared: -0.1183
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: ITRI | Test Samples: 100 | R-squared: -0.1394
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: JBL | Test Samples: 100 | R-squared: -0.0241
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: JKHY | Test Samples: 100 | R-squared: -0.4110
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: KLAC | Test Samples: 100 | R-squared: -1.1238
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: KLIC | Test Samples: 100 | R-squared: -1.4578
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: KOPN | Test Samples: 100 | R-squared: -0.2631
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: KOSS | Test Samples: 100 | R-squared: -0.4800
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: KTCC | Test Samples: 100 | R-squared: -0.4130
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: KVHI | Test Samples: 100 | R-squared: -0.1971
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: LFUS | Test Samples: 100 | R-squared: -0.4770
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: LGL | Test Samples: 100 | R-squared: -0.1037
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: LGTY | Test Samples: 100 | R-squared: -0.0420
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: LOGI | Test Samples: 100 | R-squared: -1.1727
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: LPTH | Test Samples: 100 | R-squared: -0.3962
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: LRCX | Test Samples: 100 | R-squared: -0.2306
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Ticker: LSCC | Test Samples: 100 | R-squared: -0.5171
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: LYTS | Test Samples: 100 | R-squared: -0.0027
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Ticker: MANH | Test Samples: 100 | R-squared: -0.2415
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: MCHP | Test Samples: 100 | R-squared: -1.1437
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: MEI | Test Samples: 100 | R-squared: -0.4240
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: MGIC | Test Samples: 100 | R-squared: -1.0121
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: MIND | Test Samples: 100 | R-squared: -0.0789
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: MITK | Test Samples: 100 | R-squared: -2.4967
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: MLAB | Test Samples: 100 | R-squared: -0.0514
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: MSFT | Test Samples: 100 | R-squared: -0.3798
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: MSI | Test Samples: 100 | R-squared: -0.4552
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: MSN | Test Samples: 100 | R-squared: -0.0650
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: MSTR | Test Samples: 100 | R-squared: -0.3863
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: MU | Test Samples: 100 | R-squared: -0.0633
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: MVIS | Test Samples: 100 | R-squared: 0.0376
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: NEON | Test Samples: 100 | R-squared: -0.3471
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: NICE | Test Samples: 100 | R-squared: -1.2081
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: NOK | Test Samples: 100 | R-squared: -0.1614
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: NSIT | Test Samples: 100 | R-squared: -0.1349
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: NTAP | Test Samples: 100 | R-squared: -0.9009
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: NTWK | Test Samples: 100 | R-squared: -0.0888
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: NVEC | Test Samples: 100 | R-squared: -0.2826
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: OBLG | Test Samples: 100 | R-squared: -0.1223
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: OCC | Test Samples: 100 | R-squared: -0.4616
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: OLED | Test Samples: 100 | R-squared: -0.4444
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: ORCL | Test Samples: 100 | R-squared: -2.3450
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step
# Ticker: OSIS | Test Samples: 100 | R-squared: -0.8411
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: OSPN | Test Samples: 100 | R-squared: -0.2631
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: OTEX | Test Samples: 100 | R-squared: -0.3856
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: PAR | Test Samples: 100 | R-squared: -0.1391
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: PAYX | Test Samples: 100 | R-squared: -0.1297
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: PLAB | Test Samples: 100 | R-squared: -1.5300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: PLUS | Test Samples: 100 | R-squared: -0.9994
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: PLXS | Test Samples: 100 | R-squared: -0.7886
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: POWI | Test Samples: 100 | R-squared: -0.3698
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: PRGS | Test Samples: 100 | R-squared: -0.1003
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: PTC | Test Samples: 100 | R-squared: -0.3499
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: QCOM | Test Samples: 100 | R-squared: -4.6004
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: RAMP | Test Samples: 100 | R-squared: -0.3263
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: REFR | Test Samples: 100 | R-squared: -0.0206
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Ticker: RELL | Test Samples: 100 | R-squared: -0.0248
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: RMBS | Test Samples: 100 | R-squared: -1.4842
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Ticker: ROG | Test Samples: 100 | R-squared: -0.0809
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: ROP | Test Samples: 100 | R-squared: -0.4708
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: SANM | Test Samples: 100 | R-squared: -1.2621
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: SAP | Test Samples: 100 | R-squared: -1.4011
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: SCSC | Test Samples: 100 | R-squared: -0.2165
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: SGMA | Test Samples: 100 | R-squared: -0.5730
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: SILC | Test Samples: 100 | R-squared: -0.3898
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: SMSI | Test Samples: 100 | R-squared: -0.1106
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: SMTC | Test Samples: 100 | R-squared: -0.3553
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: SNPS | Test Samples: 100 | R-squared: -0.5401
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: SONY | Test Samples: 100 | R-squared: -0.0838
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: SPNS | Test Samples: 100 | R-squared: -0.1022
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: SSYS | Test Samples: 100 | R-squared: -0.0662
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: STM | Test Samples: 100 | R-squared: -0.4319
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: SWKS | Test Samples: 100 | R-squared: -0.2234
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: TACT | Test Samples: 100 | R-squared: -0.0856
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: TAIT | Test Samples: 100 | R-squared: -0.1052
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: TCX | Test Samples: 100 | R-squared: -0.0820
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: TER | Test Samples: 100 | R-squared: -0.8770
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: TRMB | Test Samples: 100 | R-squared: -0.1971
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: TRT | Test Samples: 100 | R-squared: -0.0736
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: TSEM | Test Samples: 100 | R-squared: -0.2085
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: TSM | Test Samples: 100 | R-squared: -0.2868
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: TTEC | Test Samples: 100 | R-squared: -1.8050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: TXN | Test Samples: 100 | R-squared: -0.5972
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: TYL | Test Samples: 100 | R-squared: -0.3561
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: UEIC | Test Samples: 100 | R-squared: -0.2052
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: UIS | Test Samples: 100 | R-squared: -0.0959
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: UPBD | Test Samples: 100 | R-squared: -0.1621
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: VECO | Test Samples: 100 | R-squared: -0.1408
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: VIAV | Test Samples: 100 | R-squared: -0.2985
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: VICR | Test Samples: 100 | R-squared: -0.1911
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: VOXX | Test Samples: 100 | R-squared: -0.0742
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: VRSN | Test Samples: 100 | R-squared: -1.1558
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Ticker: VSAT | Test Samples: 100 | R-squared: -0.0593
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: VSH | Test Samples: 100 | R-squared: -0.1542
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: VYX | Test Samples: 100 | R-squared: -0.1410
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: WDC | Test Samples: 100 | R-squared: -0.1594
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: WOLF | Test Samples: 100 | R-squared: -0.8080
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: WYY | Test Samples: 100 | R-squared: -0.0474
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: XRX | Test Samples: 100 | R-squared: -0.0621
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: ZBRA | Test Samples: 100 | R-squared: -0.5131

# %%
# Convert results to DataFrame
results_df = pd.DataFrame(results_df)

# %%
# Save the results to a CSV file
results_df.to_csv("../data/model_results/lstm_results.csv", index=False)

# %% [markdown]
# # Portfolio Construction

# %%
results_df = pd.read_csv("../data/model_results/lstm_results.csv")

# %%
# Calculate cumulative returns for a portfolio comprising top 10% stocks each month
fixed_investment = 1000  # Amount to invest each month

# Create a DataFrame for cumulative returns
investment_results = []  # To store cumulative returns
cumulative_return = 0.0  # Start with zero cumulative return

# Loop through each month in the test period
for month in range(100):
    # Select the stocks for the current month
    current_month_stocks = results_df[results_df['Month'] == month]
    
    if not current_month_stocks.empty:
        # Select the top 10% stocks based on predicted returns
        top_10_percent_threshold = current_month_stocks['y_pred'].quantile(0.90)
        current_top_stocks = current_month_stocks[current_month_stocks['y_pred'] >= top_10_percent_threshold]

        # Use the risk premium as the monthly return
        monthly_returns = current_top_stocks['y_test'].values
        
        # Calculate the average risk premium of the selected top stocks
        if len(monthly_returns) > 0:
            average_monthly_return = monthly_returns.mean()  # Average risk premium
            
            # Calculate total return from the fixed investment
            cumulative_return += average_monthly_return * fixed_investment

            # Store the result for this month
            investment_results.append({
                'month': month,
                'cumulative_return': cumulative_return
            })

# Convert results to DataFrame
investment_df = pd.DataFrame(investment_results)

# Display cumulative returns
print(investment_df)
# Out:
#     month  cumulative_return
# 0       0          44.747116
# 1       1         101.230880
# 2       2         203.137134
# 3       3         257.035285
# 4       4         263.483423
# ..    ...                ...
# 95     95        1925.245627
# 96     96        1870.305186
# 97     97        1901.169725
# 98     98        1850.234042
# 99     99        1832.150469
#
# [100 rows x 2 columns]
