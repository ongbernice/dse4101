# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score

# %%
# Load the dataset
stocks_data = pd.read_csv("../data/final_merged_data.csv", parse_dates=["Date"])
stocks_data = stocks_data.iloc[:, 1:]

# %% [markdown]
# # Data Preparation

# %%
# get names of feature columns
features = stocks_data.drop(columns=['Date', 'Ticker', 'Risk_Premium', 'Risk_Premium_lag_1']).columns
target = 'Risk_Premium'

# impute missing values
imputer = SimpleImputer(strategy='mean')
stocks_data[features] = imputer.fit_transform(stocks_data[features])

# ticker names
tickers = stocks_data['Ticker'].unique()

# %%
def create_sequences(X, y, n_steps=12):
    """
    Create sliding window sequences for RNN models.
    
    :param X: Feature DataFrame
    :param y: Target series
    :param n_steps: Number of timesteps for each input sequence
    :return: Arrays of input sequences (X_seq) and corresponding targets (y_seq)
    """
    X_seq, y_seq = [], []
    for i in range(len(X) - n_steps):
        X_seq.append(X.iloc[i:i + n_steps].values)  # Get sequence of features
        y_seq.append(y.iloc[i + n_steps])          # Get corresponding target value
    
    return np.array(X_seq), np.array(y_seq)

# Dictionaries to store sequences and scalers per ticker
X_tickers = {}
y_tickers = {}
scalers = {}

# Loop through each ticker first
for ticker in tickers:
    # Select rows for the current ticker
    ticker_data = stocks_data[stocks_data['Ticker'] == ticker]

    # Separate features (X) and target variable (y)
    X_df = ticker_data[features]  # Select feature columns
    y_df = ticker_data[['Risk_Premium']]  # Select target column

    # Create separate scalers for X and y
    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    # Fit & transform the features and target separately
    X_scaled = scaler_x.fit_transform(X_df)
    y_scaled = scaler_y.fit_transform(y_df)

    # Convert back to DataFrame for sequence creation
    X_scaled_df = pd.DataFrame(X_scaled, columns=X_df.columns, index=X_df.index)
    y_scaled_df = pd.DataFrame(y_scaled, columns=y_df.columns, index=y_df.index)

    # Create sequences
    X_seq, y_seq = create_sequences(X_scaled_df, y_scaled_df)

    # --- Split the sequences into training and testing sets ---
    # Ensure there are at least 160 training and 100 test samples
    X_train = X_seq[:-100]
    y_train = y_seq[:-100]
    X_test = X_seq[-100:]
    y_test = y_seq[-100:]

    # Store results in dictionaries
    X_tickers[ticker] = {'train': X_train, 'test': X_test}
    y_tickers[ticker] = {'train': y_train, 'test': y_test}
    
    # Store scalers for later inverse transformation
    scalers[ticker] = {'X_scaler': scaler_x, 'y_scaler': scaler_y}

# %% [markdown]
# # Model Training & Evaluation per Ticker

# %%
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(Input(shape=input_shape))  # Explicit Input layer
    model.add(LSTM(50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))  # Single output for risk premium
    model.compile(optimizer="adam", loss="mean_squared_error")
    return model

# %%
# Dictionary to store evaluation results for each ticker
results = {}

for ticker in X_tickers:
    X_train = X_tickers[ticker]['train']  # Shape: (num_train_samples, sequence_length, num_features)
    y_train = y_tickers[ticker]['train']
    X_test = X_tickers[ticker]['test']    # Shape: (100, sequence_length, num_features)
    y_test = y_tickers[ticker]['test']
    
    # Get scalers for the ticker
    scaler_y = scalers[ticker]['y_scaler']

    # Define the input shape based on the training set
    input_shape = X_train.shape[1:]  # (sequence_length, num_features)
    
    # Create and train the model
    model = create_lstm_model(input_shape)
    model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred_scaled = model.predict(X_test).flatten().reshape(-1, 1)

    # Inverse transform predictions and true values
    y_pred = scaler_y.inverse_transform(y_pred_scaled).flatten()
    y_test_original = scaler_y.inverse_transform(y_test).flatten()

    # Compute the R-squared value
    r2 = r2_score(y_test_original, y_pred)
    
    # Store results
    results[ticker] = {
        'r_squared': r2,
        'y_test': y_test_original,
        'y_pred': y_pred
    }
    
    print(f"Ticker: {ticker} | Test Samples: {X_test.shape[0]} | R-squared: {r2:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# Ticker: AAPL | Test Samples: 100 | R-squared: -1.1284
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Ticker: ACIW | Test Samples: 100 | R-squared: -0.1318
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: ADBE | Test Samples: 100 | R-squared: -1.4246
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Ticker: ADI | Test Samples: 100 | R-squared: -0.7136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Ticker: ADP | Test Samples: 100 | R-squared: -0.2394
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Ticker: ADSK | Test Samples: 100 | R-squared: -0.4563
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Ticker: ADTN | Test Samples: 100 | R-squared: -1.2356
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Ticker: AEHR | Test Samples: 100 | R-squared: -0.0805
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Ticker: AGYS | Test Samples: 100 | R-squared: -0.2685
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: ALNT | Test Samples: 100 | R-squared: -1.0863
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Ticker: ALOT | Test Samples: 100 | R-squared: -0.7251
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Ticker: AMAT | Test Samples: 100 | R-squared: -0.1022
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: AMD | Test Samples: 100 | R-squared: -0.6972
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: AMKR | Test Samples: 100 | R-squared: -0.1644
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: ANSS | Test Samples: 100 | R-squared: -0.1591
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: APH | Test Samples: 100 | R-squared: -0.2616
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Ticker: ARW | Test Samples: 100 | R-squared: -0.3655
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: ASGN | Test Samples: 100 | R-squared: -0.4705
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Ticker: ASML | Test Samples: 100 | R-squared: -0.2897
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: ASTC | Test Samples: 100 | R-squared: -0.2150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Ticker: ASUR | Test Samples: 100 | R-squared: -0.2039
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: ASYS | Test Samples: 100 | R-squared: -0.1290
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Ticker: AVNW | Test Samples: 100 | R-squared: 0.0652
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: AVT | Test Samples: 100 | R-squared: -0.2207
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: AWRE | Test Samples: 100 | R-squared: -0.1688
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Ticker: AXTI | Test Samples: 100 | R-squared: -0.0773
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: AZPN | Test Samples: 100 | R-squared: -1.2928
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: BDC | Test Samples: 100 | R-squared: -0.1289
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: BELFA | Test Samples: 100 | R-squared: -0.0660
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step
# Ticker: BELFB | Test Samples: 100 | R-squared: -0.0578
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: BHE | Test Samples: 100 | R-squared: -0.3449
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: BKTI | Test Samples: 100 | R-squared: -0.5983
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: BMI | Test Samples: 100 | R-squared: -0.2966
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Ticker: BOSC | Test Samples: 100 | R-squared: -0.1530
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: CACI | Test Samples: 100 | R-squared: -0.3063
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: CCRD | Test Samples: 100 | R-squared: -0.2276
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: CDNS | Test Samples: 100 | R-squared: -0.4589
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: CGNX | Test Samples: 100 | R-squared: -0.1310
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: CHKP | Test Samples: 100 | R-squared: -0.2157
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: CIEN | Test Samples: 100 | R-squared: -0.3468
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: CLFD | Test Samples: 100 | R-squared: -0.1504
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: CLMB | Test Samples: 100 | R-squared: -0.5689
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: CLRO | Test Samples: 100 | R-squared: -0.7754
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: CLS | Test Samples: 100 | R-squared: -0.5395
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: CMTL | Test Samples: 100 | R-squared: -0.2918
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Ticker: CNXN | Test Samples: 100 | R-squared: -1.9082
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: COHR | Test Samples: 100 | R-squared: -0.2597
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: COHU | Test Samples: 100 | R-squared: -0.2743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Ticker: CPSH | Test Samples: 100 | R-squared: -0.5119
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: CRUS | Test Samples: 100 | R-squared: -0.1396
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: CSCO | Test Samples: 100 | R-squared: -0.1802
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: CSGS | Test Samples: 100 | R-squared: -0.3423
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: CSPI | Test Samples: 100 | R-squared: -0.1737
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: CTS | Test Samples: 100 | R-squared: -1.0931
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: CTSH | Test Samples: 100 | R-squared: -0.6551
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: DAIO | Test Samples: 100 | R-squared: -0.2709
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: DAKT | Test Samples: 100 | R-squared: -0.1586
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: DDD | Test Samples: 100 | R-squared: -0.0046
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Ticker: DGII | Test Samples: 100 | R-squared: -0.5943
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: DIOD | Test Samples: 100 | R-squared: -0.1841
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: DJCO | Test Samples: 100 | R-squared: -0.3916
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: DOX | Test Samples: 100 | R-squared: -0.3284
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: DSWL | Test Samples: 100 | R-squared: -0.0658
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: DXC | Test Samples: 100 | R-squared: -0.0705
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: EEFT | Test Samples: 100 | R-squared: -0.0276
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: EGHT | Test Samples: 100 | R-squared: -0.1808
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: ELSE | Test Samples: 100 | R-squared: -0.4778
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: ELTK | Test Samples: 100 | R-squared: -0.1232
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: EMKR | Test Samples: 100 | R-squared: -0.5898
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: ERIC | Test Samples: 100 | R-squared: -1.1151
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: ESE | Test Samples: 100 | R-squared: -0.8488
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: FARO | Test Samples: 100 | R-squared: -0.1093
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: FEIM | Test Samples: 100 | R-squared: -0.9917
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: FI | Test Samples: 100 | R-squared: -0.0766
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: FICO | Test Samples: 100 | R-squared: -1.5760
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: FLEX | Test Samples: 100 | R-squared: -0.2253
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: FORTY | Test Samples: 100 | R-squared: -0.0457
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: GEN | Test Samples: 100 | R-squared: -0.0973
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: GIB | Test Samples: 100 | R-squared: -0.7516
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: GILT | Test Samples: 100 | R-squared: -0.8082
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Ticker: GLW | Test Samples: 100 | R-squared: -5.9052
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: GNSS | Test Samples: 100 | R-squared: -0.7707
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: HCKT | Test Samples: 100 | R-squared: -0.2346
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step
# Ticker: HLIT | Test Samples: 100 | R-squared: -0.1622
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: HPQ | Test Samples: 100 | R-squared: -0.0670
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Ticker: IBM | Test Samples: 100 | R-squared: -0.4069
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Ticker: IDCC | Test Samples: 100 | R-squared: -4.2408
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Ticker: INOD | Test Samples: 100 | R-squared: -1.2454
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# Ticker: INTC | Test Samples: 100 | R-squared: -0.5738
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# Ticker: INTT | Test Samples: 100 | R-squared: -0.2427
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: INTU | Test Samples: 100 | R-squared: -0.2932
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: INTZ | Test Samples: 100 | R-squared: -0.0779
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: INUV | Test Samples: 100 | R-squared: -0.1864
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Ticker: IT | Test Samples: 100 | R-squared: -0.0219
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Ticker: ITRI | Test Samples: 100 | R-squared: 0.0074
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: JBL | Test Samples: 100 | R-squared: -0.5914
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: JKHY | Test Samples: 100 | R-squared: -2.5310
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: KLAC | Test Samples: 100 | R-squared: -0.1297
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Ticker: KLIC | Test Samples: 100 | R-squared: -0.5004
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: KOPN | Test Samples: 100 | R-squared: -0.3347
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: KOSS | Test Samples: 100 | R-squared: -0.1313
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: KTCC | Test Samples: 100 | R-squared: -1.0127
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Ticker: KVHI | Test Samples: 100 | R-squared: -0.7757
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: LFUS | Test Samples: 100 | R-squared: -0.4227
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: LGL | Test Samples: 100 | R-squared: -0.4034
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: LGTY | Test Samples: 100 | R-squared: -0.1407
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: LOGI | Test Samples: 100 | R-squared: -0.2359
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: LPTH | Test Samples: 100 | R-squared: -0.2932
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Ticker: LRCX | Test Samples: 100 | R-squared: -0.1526
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: LSCC | Test Samples: 100 | R-squared: -0.2255
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Ticker: LYTS | Test Samples: 100 | R-squared: -0.0016
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Ticker: MANH | Test Samples: 100 | R-squared: -0.1340
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Ticker: MCHP | Test Samples: 100 | R-squared: -0.7669
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Ticker: MEI | Test Samples: 100 | R-squared: -1.6496
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Ticker: MGIC | Test Samples: 100 | R-squared: -0.6701
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Ticker: MIND | Test Samples: 100 | R-squared: -0.2334
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Ticker: MITK | Test Samples: 100 | R-squared: -0.6503
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Ticker: MLAB | Test Samples: 100 | R-squared: -0.3664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Ticker: MSFT | Test Samples: 100 | R-squared: -0.4608
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step
# Ticker: MSI | Test Samples: 100 | R-squared: -0.6833
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step
# Ticker: MSN | Test Samples: 100 | R-squared: -0.1844
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step
# Ticker: MSTR | Test Samples: 100 | R-squared: -0.0451
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# Ticker: MU | Test Samples: 100 | R-squared: -0.6972
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Ticker: MVIS | Test Samples: 100 | R-squared: -0.3900
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Ticker: NEON | Test Samples: 100 | R-squared: -0.0574
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step
# Ticker: NICE | Test Samples: 100 | R-squared: -4.2013
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step
# Ticker: NOK | Test Samples: 100 | R-squared: -0.4780
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step
# Ticker: NSIT | Test Samples: 100 | R-squared: -0.3335
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step
# Ticker: NTAP | Test Samples: 100 | R-squared: -0.7364
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step
# Ticker: NTWK | Test Samples: 100 | R-squared: -0.1387
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Ticker: NVEC | Test Samples: 100 | R-squared: -5.7268
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Ticker: OBLG | Test Samples: 100 | R-squared: -0.0871
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Ticker: OCC | Test Samples: 100 | R-squared: -0.5646
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Ticker: OLED | Test Samples: 100 | R-squared: -0.0805
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Ticker: ORCL | Test Samples: 100 | R-squared: -0.1243
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Ticker: OSIS | Test Samples: 100 | R-squared: -0.2041
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Ticker: OSPN | Test Samples: 100 | R-squared: -0.1209
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Ticker: OTEX | Test Samples: 100 | R-squared: -0.1967
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step
# Ticker: PAR | Test Samples: 100 | R-squared: -1.4155
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Ticker: PAYX | Test Samples: 100 | R-squared: -0.0348
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Ticker: PLAB | Test Samples: 100 | R-squared: -2.2793
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Ticker: PLUS | Test Samples: 100 | R-squared: -0.1382
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Ticker: PLXS | Test Samples: 100 | R-squared: -0.0247
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Ticker: POWI | Test Samples: 100 | R-squared: -0.3866
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: PRGS | Test Samples: 100 | R-squared: -0.2818
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: PTC | Test Samples: 100 | R-squared: -0.9248
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# Ticker: QCOM | Test Samples: 100 | R-squared: -0.5159
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step
# Ticker: RAMP | Test Samples: 100 | R-squared: 0.0120
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step
# Ticker: REFR | Test Samples: 100 | R-squared: -0.0081
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# Ticker: RELL | Test Samples: 100 | R-squared: -0.3923
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step
# Ticker: RMBS | Test Samples: 100 | R-squared: -3.9886
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Ticker: ROG | Test Samples: 100 | R-squared: -0.0197
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step
# Ticker: ROP | Test Samples: 100 | R-squared: -0.0601
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Ticker: SANM | Test Samples: 100 | R-squared: -0.9780
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Ticker: SAP | Test Samples: 100 | R-squared: -0.4130
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Ticker: SCSC | Test Samples: 100 | R-squared: -0.0654
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Ticker: SGMA | Test Samples: 100 | R-squared: -0.3062
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Ticker: SILC | Test Samples: 100 | R-squared: -0.0500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Ticker: SMSI | Test Samples: 100 | R-squared: -1.0383
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# Ticker: SMTC | Test Samples: 100 | R-squared: -0.2604
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Ticker: SNPS | Test Samples: 100 | R-squared: -0.9998
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Ticker: SONY | Test Samples: 100 | R-squared: -0.4286
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Ticker: SPNS | Test Samples: 100 | R-squared: -0.4805
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Ticker: SSYS | Test Samples: 100 | R-squared: -0.0297
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Ticker: STM | Test Samples: 100 | R-squared: -0.3803
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: SWKS | Test Samples: 100 | R-squared: -0.9131
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: TACT | Test Samples: 100 | R-squared: -0.3729
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Ticker: TAIT | Test Samples: 100 | R-squared: -0.3832
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Ticker: TCX | Test Samples: 100 | R-squared: -0.5925
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Ticker: TER | Test Samples: 100 | R-squared: -0.7841
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Ticker: TRMB | Test Samples: 100 | R-squared: -0.3050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Ticker: TRT | Test Samples: 100 | R-squared: -0.1434
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: TSEM | Test Samples: 100 | R-squared: -1.7653
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Ticker: TSM | Test Samples: 100 | R-squared: -0.2569
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: TTEC | Test Samples: 100 | R-squared: -0.2743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Ticker: TXN | Test Samples: 100 | R-squared: -0.1103
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Ticker: TYL | Test Samples: 100 | R-squared: -0.5138
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# Ticker: UEIC | Test Samples: 100 | R-squared: -0.1262
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: UIS | Test Samples: 100 | R-squared: -0.0880
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: UPBD | Test Samples: 100 | R-squared: -0.0289
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: VECO | Test Samples: 100 | R-squared: -0.2111
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: VIAV | Test Samples: 100 | R-squared: -0.3538
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Ticker: VICR | Test Samples: 100 | R-squared: -0.4821
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Ticker: VOXX | Test Samples: 100 | R-squared: -0.0123
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Ticker: VRSN | Test Samples: 100 | R-squared: -1.4807
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: VSAT | Test Samples: 100 | R-squared: -0.0433
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Ticker: VSH | Test Samples: 100 | R-squared: -0.2491
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Ticker: VYX | Test Samples: 100 | R-squared: -0.0220
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: WDC | Test Samples: 100 | R-squared: -0.1593
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Ticker: WOLF | Test Samples: 100 | R-squared: -0.2428
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Ticker: WYY | Test Samples: 100 | R-squared: -0.0690
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Ticker: XRX | Test Samples: 100 | R-squared: -0.1111
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Ticker: ZBRA | Test Samples: 100 | R-squared: -0.7828
#
# Summary of R-squared values:
#     Ticker  R_squared                                             y_test  \
# 0     AAPL  -1.128351  [-0.015228273620126955, 0.09588202549900146, 0...
# 1     ACIW  -0.131831  [0.11054586580127031, 0.019107797478108285, 0....
# 2     ADBE  -1.424551  [0.13510051643079743, 0.0433968551073797, 0.04...
# 3      ADI  -0.713568  [0.02398170360694782, 0.04732117120453972, -0....
# 4      ADP  -0.239408  [0.01694418121828438, 0.042263806023586106, 0....
# ..     ...        ...                                                ...
# 188    WDC  -0.159332  [0.022380869037584978, 0.10197700256011641, 0....
# 189   WOLF  -0.242807  [0.08449991994381963, 0.008637802101814206, -0...
# 190    WYY  -0.069023  [-0.02217810489620562, -0.10162355697818526, 0...
# 191    XRX  -0.111108  [0.030862113472095377, -0.02910678970090082, 0...
# 192   ZBRA  -0.782779  [-0.0010771294335190876, 0.0598599630620765, 0...
#
#                                                 y_pred
# 0    [-0.009177392, -0.006309078, -0.0012141059, 0....
# 1    [0.07656764, 0.07085673, 0.064736195, 0.059425...
# 2    [0.0037313101, -0.001493722, -0.0021345827, -0...
# 3    [0.02671867, 0.025061315, 0.021099769, 0.01534...
# 4    [0.0018986921, 0.0009194287, 0.0007145353, -0....
# ..                                                 ...
# 188  [0.04476336, 0.047572363, 0.045555264, 0.04332...
# 189  [0.012696216, 0.014260862, 0.015210944, 0.0173...
# 190  [0.094689324, 0.08990828, 0.09195933, 0.101234...
# 191  [0.037505295, 0.037694775, 0.038776483, 0.0388...
# 192  [-0.00836299, -0.01023777, -0.013368026, -0.01...
#
# [193 rows x 4 columns]

# %%
# create a summary DataFrame of R-squared values
results_df = pd.DataFrame({
    'Ticker': list(results.keys()),
    'R_squared': [results[ticker]['r_squared'] for ticker in results],
    'y_test': [results[ticker]['y_test'] for ticker in results],
    'y_pred': [results[ticker]['y_pred'] for ticker in results]
})

# %%
# Save the results to a CSV file
results_df.to_csv("../data/model_results/lstm_results.csv", index=False)

# %% [markdown]
# # Portfolio Construction

# %%
# Calculate cumulative returns for a portfolio comprising top 10% stocks each month
fixed_investment = 1000  # Amount to invest each month

# Create a DataFrame for cumulative returns
investment_results = []  # To store cumulative returns
cumulative_return = 0.0  # Start with zero cumulative return

# Loop through each month in the test period
for month in range(100):
    # Select the stocks for the current month
    current_month_stocks = results_df.copy()
    current_month_stocks['predicted_return'] = current_month_stocks['Ticker'].apply(lambda ticker: results[ticker]['y_pred'][month])
    current_month_stocks['actual_return'] = current_month_stocks['Ticker'].apply(lambda ticker: results[ticker]['y_test'][month])

    if not current_month_stocks.empty:
        # Select the top 10% stocks based on predicted returns
        top_10_percent_threshold = current_month_stocks['predicted_return'].quantile(0.90)
        current_top_stocks = current_month_stocks[current_month_stocks['predicted_return'] >= top_10_percent_threshold]

        # Use the risk premium as the monthly return
        monthly_returns = current_top_stocks['actual_return'].values
        
        # Calculate the average risk premium of the selected top stocks
        if len(monthly_returns) > 0:
            average_monthly_return = monthly_returns.mean()  # Average risk premium
            
            # Calculate total return from the fixed investment
            cumulative_return += average_monthly_return * fixed_investment

            # Store the result for this month
            investment_results.append({
                'month': month,
                'cumulative_return': cumulative_return
            })

# Convert results to DataFrame
investment_df = pd.DataFrame(investment_results)

# Display cumulative returns
print(investment_df)
# Out:
#     month  cumulative_return
# 0       0          53.855206
# 1       1          85.219464
# 2       2         195.984762
# 3       3         288.340293
# 4       4         297.375297
# ..    ...                ...
# 95     95        1427.536883
# 96     96        1399.320129
# 97     97        1502.325265
# 98     98        1437.949355
# 99     99        1447.096736
#
# [100 rows x 2 columns]
